# %% [markdown]
# # module 2
#
# 1.	Найдите обратную матрицу
# ![image.png](attachment:image.png)
# 2.	Решите методом обратных матриц матричные уравнения, полученные вами в предыдущем модуле. Проверьте себя с помощью sympy
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##

# %%
from sympy import *

init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
# assign matrix X and symbols x, y, a, b

x, y, a, b, c, d = symbols('x, y, a, b, c, d')


X
# Out:
# [    d         -b    ]
# [---------  ---------]
# [a*d - b*c  a*d - b*c]
# [                    ]
# [   -c          a    ]
# [---------  ---------]
# [a*d - b*c  a*d - b*c]

# %%
a, b, c, d = 2, 5, 7, -3

X = (1/(a*d - b*c))*Matrix([[d, -b], [-c, a]])
result = X * Matrix([11, -23])
result
# Out:
# [-2.0]
# [    ]
# [3.0 ]
